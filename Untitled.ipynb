# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import pandas as pd
import pandas_gbq

# %%
DATABASE_NAME = "etl"
PROJECT_ID = "new-life-400922"
TABLE_NAME = "res_tickers_history"

# %%
source = f'{PROJECT_ID}.{DATABASE_NAME}.{TABLE_NAME}'
sql = """
    SELECT *
    FROM `new-life-400922.etl.res_tickers_history`
"""
# Run a Standard SQL query with the project set explicitly

df = pd.read_gbq(sql, project_id=PROJECT_ID, dialect="standard")

# %%
df.head(10)
# Out:
#   ticker       title          type         cik       sic_description  \
# 0   AAPL  Apple Inc.  Common Stock  0000320193  ELECTRONIC COMPUTERS
# 1   AAPL  Apple Inc.  Common Stock  0000320193  ELECTRONIC COMPUTERS
# 2   AAPL  Apple Inc.  Common Stock  0000320193  ELECTRONIC COMPUTERS
# 3   AAPL  Apple Inc.  Common Stock  0000320193  ELECTRONIC COMPUTERS
# 4   AAPL  Apple Inc.  Common Stock  0000320193  ELECTRONIC COMPUTERS
# 5   AAPL  Apple Inc.  Common Stock  0000320193  ELECTRONIC COMPUTERS
# 6   AAPL  Apple Inc.  Common Stock  0000320193  ELECTRONIC COMPUTERS
# 7   AAPL  Apple Inc.  Common Stock  0000320193  ELECTRONIC COMPUTERS
# 8   AAPL  Apple Inc.  Common Stock  0000320193  ELECTRONIC COMPUTERS
# 9   AAPL  Apple Inc.  Common Stock  0000320193  ELECTRONIC COMPUTERS
#
#          date  volume_weighted_average_price  cash_amount  \
# 0  2018-10-12                        55.1283          NaN
# 1  2018-10-15                        54.6710          NaN
# 2  2018-10-16                        55.0193          NaN
# 3  2018-10-17                        55.2595          NaN
# 4  2018-10-18                        54.2580          NaN
# 5  2018-10-19                        54.8459          NaN
# 6  2018-10-22                        55.3197          NaN
# 7  2018-10-23                        54.7125          NaN
# 8  2018-10-24                        54.8292          NaN
# 9  2018-10-25                        54.8501          NaN
#
#    weighted_shares_outstanding num_tickers  transactions     volume
# 0                  15634232000        AAPL        343455  161351404
# 1                  15634232000        AAPL        257521  123164028
# 2                  15634232000        AAPL        267901  116735852
# 3                  15634232000        AAPL        227312   91541588
# 4                  15634232000        AAPL        311070  130325260
# 5                  15634232000        AAPL        290875  132308304
# 6                  15634232000        AAPL        263533  115084328
# 7                  15634232000        AAPL        382393  155071384
# 8                  15634232000        AAPL        388910  163700652
# 9                  15634232000        AAPL        278369  119423072

# %%
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.plot(df['volume_weighted_average_price'])

plt.show()
